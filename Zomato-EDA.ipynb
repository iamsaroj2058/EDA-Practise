# %%
# converting json to CSv file
import json
import csv

# Load JSON file
with open("file1.json", "r") as json_file:
    data = json.load(json_file)

# Get column names
keys = data[0].keys()

# Write CSV file
with open("zomato.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=keys, extrasaction='ignore')

    writer.writeheader()
    writer.writerows(data)

print("JSON converted to CSV successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 17
#      14     writer = csv.DictWriter(csv_file, fieldnames=keys)
#      16     writer.writeheader()
# ---> 17     writer.writerows(data)
#      19 print("JSON converted to CSV successfully!")
#
# File d:\Anaconda\envs\dailyml\lib\csv.py:157, in DictWriter.writerows(self, rowdicts)
#     156 def writerows(self, rowdicts):
# --> 157     return self.writer.writerows(map(self._dict_to_list, rowdicts))
#
# File d:\Anaconda\envs\dailyml\lib\csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'status', 'message', 'code'
